# %%
import random
import hashlib as hasher

def hashbits(input):
    hash_obj = hasher.sha256()
    inputbytes = input.encode()
    hash_obj.update(inputbytes)
    hashbytes = hash_obj.digest()
    return ''.join(f'{x:08b}' for x in hashbytes)

def numberOfInitZeros(hashStr):
    count = 0
    for i in range (0 , len(hashStr)):
        if hashStr[i] == '1':
            break
        count += 1
    return count

class Block:
    def __init__(self, data, creator=None, previous=None, nonce=0):
        self.data = data
        if previous is None:
            self.previous = None
            self.previous_hash = ""
            if creator != None:
                self.creator = Miner(0 , creator.networkingPower, creator.miner_type ,"0")
            else:
                self.creator = Miner(0 , None, None, "0")
            self.height = 0
        else:
            self.previous = previous
            self.previous_hash = previous.hash
            self.creator = creator
            self.height = previous.height+1
        self.nonce = nonce
        self.hash = self.hash_block()
        self.children = []

    def hash_block(self):
        return hashbits(self.data+ self.creator.name + self.previous_hash + str(self.nonce))

    def print(self):
        print(self.data + " "+ self.creator.name + " " + str(self.height))
    
class Blockchain:
    def __init__(self, genesis_data, difficulty):
        self.chain = []
        self.chain.append(Block(genesis_data))
        self.difficulty = difficulty
        self.size = 0

    def longestChain(self, miner_networking_power, miner_type):
        max = self.chain[0].height
        for block in self.chain:
            if block.height > max:
                max = block.height
        maxes = [block for block in self.chain if block.height == max]
        
        new_maxes = []
        if len(maxes) > 1:
            chances = list(range(1, 101, 1))
            choice = random.choice(chances)
            for block in maxes:
                """
                if choice <= miner_networking_power and miner_type == block.creator.miner_type:
                    # Miner type(honest/selfish) wins, the other type(honest/selfish) loses
                    new_maxes.append(block)
                elif choice > miner_networking_power and miner_type != block.creator.miner_type:
                    # Miner type(honest/selfish) loses, the other type(honest/selfish) wins
                    new_maxes.append(block)
                """
                if choice <= block.creator and miner_type == block.creator.miner_type:
                    # Miner type(honest/selfish) wins, the other type(honest/selfish) loses
                    new_maxes.append(block)
                elif choice > miner_networking_power and miner_type != block.creator.miner_type:
                    # Miner type(honest/selfish) loses, the other type(honest/selfish) wins
                    new_maxes.append(block)
                    
            if len(new_maxes) == 0:
                new_maxes = maxes
        else:
            new_maxes = maxes

        return new_maxes[0]
        
    def add(self, newBlock):
        self.chain.append(newBlock)
        newBlock.previous.children.append(newBlock)
        self.size +=1
        
    def print(self):
        for block in self.chain:
            block.print()
            print("________")

    def hasFork(self):
        for block1 in self.chain:
            for block2 in self.chain:
                if block1!=block2 and block1.height == block2.height:
                    return True
        return False

    def checkMiner(self, miner):
        last = self.longestChain(miner.networkingPower, miner.miner_type)
        count = 0
        while last!=None:
            if last.creator == miner:
                count += 1
            last = last.previous
        return count
    
    # miner A - how many blocks are built on top of the blocks of miner A?
    def gammaMiner(self, miner): 
        last = self.longestChain(miner.networkingPower, miner.miner_type)
        count = 0 # block 0 (miner A) -> block 1 (miner B) -> block 2 (miner A)
        while last!=None:
            last_creator =  last.creator
            if last_creator != miner and last.previous.creator == miner:
                count += 1
            last = last.previous
        return count
            
class Miner:
    def __init__(self, miningPower, networkingPower, miner_type, name, blockchain=None):
        self.miningPower = miningPower
        self.networkingPower = networkingPower
        self.miner_type = miner_type
        self.nonce = random.randint(0,100000)
        self.name = name
        self.blockchain = blockchain
        if self.blockchain != None:
            self.lastBlock = blockchain.longestChain(self.networkingPower, self.miner_type)
  
    def UpdateLast(self):
        latest = self.blockchain.longestChain(self.networkingPower, self.miner_type)
        if latest.height > self.lastBlock.height:
            self.lastBlock = latest
        
    def PoWSolver(self):
        for i in range (0 , self.miningPower):
            newBlock = Block(str(self.blockchain.size), self, self.lastBlock, self.nonce)
            h = newBlock.hash_block()
            count = numberOfInitZeros(h)
            if count >= bc.difficulty:
                bc.add(newBlock)
                self.lastBlock = newBlock
            self.nonce += 1

class SelfishMiner(Miner):
    def __init__(self, miningPower, networkingPower, miner_type, name, blockchain=None):
        super().__init__(miningPower, networkingPower, miner_type, name, blockchain)
        self.privateBlocks = []
        self.publishNext = False

    def UpdateLast(self):
        #add this function
        latest = self.blockchain.longestChain(self.networkingPower, self.miner_type)
        publicheight = latest.height
        if publicheight > self.lastBlock.height:
            self.privateBlocks = []
            self.lastBlock = latest
            self.publishNext = False
        if publicheight == self.lastBlock.height-1 and len(self.privateBlocks)> 1:
            for block in self.privateBlocks:
                self.blockchain.add(block)
                self.privateBlocks = []
        if publicheight == self.lastBlock.height:
            for block in self.privateBlocks:
                self.blockchain.add(block)
                self.privateBlocks = []
                self.publishNext = True

    def PoWSolver(self):
        for i in range (0 , self.miningPower):
            newBlock = Block(str(self.blockchain.size), self, self.lastBlock, self.nonce)
            h = newBlock.hash_block()
            count = numberOfInitZeros(h)
            if count >= bc.difficulty:
                if self.publishNext:
                    self.blockchain.add(newBlock)
                    self.publishNext = False
                else:
                    self.privateBlocks.append(newBlock)
                self.lastBlock = newBlock
            self.nonce += 1

# %%
def make_miners(type_of_minors, networking_power, num_of_miners, total_mining_power, blockchain):
    miners = []
    remaining_mining_power = total_mining_power
    
    while remaining_mining_power > 0:
        if len(miners) == num_of_miners-1:
            mining_power = remaining_mining_power
        else:
            mining_power = round(total_mining_power/num_of_miners)
        
        if type_of_minors == "honest":
            miner = Miner(mining_power, networking_power, "Honest", f"Honest miner nr. {len(miners)+1}", blockchain)
        elif type_of_minors == "selfish":
            miner = SelfishMiner(mining_power, networking_power, "Selfish", f"Selfish miner nr. {len(miners)+1}", blockchain)
        
        miners.append(miner)
        remaining_mining_power -= mining_power
        
    return miners

def simulate_selfish_mining(bc, legal_miners, selfish_miners):
    run_to = 101
    while bc.size < run_to:
        for s in selfish_miners:
            s.PoWSolver()

        for m in legal_miners:
            m.PoWSolver()

        for s in selfish_miners:
            s.UpdateLast()

        for m in legal_miners:
            m.UpdateLast()
    
    selfish_profit = 0
    for miner in selfish_miners:
        bc_height = bc.longestChain(miner.networkingPower, miner.miner_type).height
        percentage_of_miner_blocks = bc.checkMiner(miner) / bc_height
        selfish_profit += percentage_of_miner_blocks
    
    honest_profit = 0
    for miner in legal_miners:
        bc_height = bc.longestChain(miner.networkingPower, miner.miner_type).height
        percentage_of_miner_blocks = bc.checkMiner(miner) / bc_height
        honest_profit += percentage_of_miner_blocks
        
    return selfish_profit, honest_profit

# %%
### The effect of network power on selfish mining
### Modelling 50 honest miners and 50 selfish miner, each with 50% of total mining power

output = True
selfish_profits = []
honest_profits = []
sim_range_selfish = range(0, 100, 1)
sim_range_honest = range(100, 0, -1)

for i in sim_range_selfish:
    num_of_selfish_miners = 50
    num_of_honest_miners = 50
    
    total_mining_power = 100
    honest_power_share = round(num_of_honest_miners/100, 2)
    selfish_power_share = round(num_of_selfish_miners/100, 2)
    honest_mining_power = round(total_mining_power * honest_power_share)
    selfish_mining_power = round(total_mining_power * selfish_power_share)
    
    selfish_networking_power = i
    honest_networking_power = 100-i
    
    bc = Blockchain("0" , 11)
    
    honest_miners = make_miners("honest", honest_networking_power, num_of_honest_miners, honest_mining_power, bc)
    
    selfish_miners = make_miners("selfish", selfish_networking_power, num_of_selfish_miners, selfish_mining_power, bc)
        
    if output:
        print(f"Running simulation of networking power with:")
        print(f"-> {len(honest_miners)} honest minors having {honest_networking_power}% of total networking power")
        print(f"-> {len(selfish_miners)} selfish minors having {selfish_networking_power}% of total networking power")
        print("...")
        
    selfish_profit, honest_profit = simulate_selfish_mining(bc, honest_miners, selfish_miners)
    selfish_profits.append(selfish_profit)
    honest_profits.append(honest_profit)
    
    if output:
        print(f"Honest profit: {honest_profit}")
        print(f"Selfish profit: {selfish_profit}")
        print(f"Total profit: {selfish_profit+honest_profit}")
        print()
# Out:
# Running simulation of networking power with:
# -> 50 honest minors having 100% of total networking power
# -> 50 selfish minors having 0% of total networking power
# ...
# Honest profit: 1.0000000000000002
# Selfish profit: 0.0
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 99% of total networking power
# -> 50 selfish minors having 1% of total networking power
# ...
# Honest profit: 0.9333333333333338
# Selfish profit: 0.06666666666666667
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 98% of total networking power
# -> 50 selfish minors having 2% of total networking power
# ...
# Honest profit: 0.9200000000000005
# Selfish profit: 0.08
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 97% of total networking power
# -> 50 selfish minors having 3% of total networking power
# ...
# Honest profit: 0.9600000000000004
# Selfish profit: 0.04
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 96% of total networking power
# -> 50 selfish minors having 4% of total networking power
# ...
# Honest profit: 0.8823529411764708
# Selfish profit: 0.11764705882352941
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 95% of total networking power
# -> 50 selfish minors having 5% of total networking power
# ...
# Honest profit: 0.9555555555555557
# Selfish profit: 0.044444444444444446
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 94% of total networking power
# -> 50 selfish minors having 6% of total networking power
# ...
# Honest profit: 0.913793103448276
# Selfish profit: 0.08620689655172414
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 93% of total networking power
# -> 50 selfish minors having 7% of total networking power
# ...
# Honest profit: 0.87037037037037
# Selfish profit: 0.12962962962962962
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 92% of total networking power
# -> 50 selfish minors having 8% of total networking power
# ...
# Honest profit: 0.8627450980392157
# Selfish profit: 0.11764705882352941
# Total profit: 0.9803921568627452
#
# Running simulation of networking power with:
# -> 50 honest minors having 91% of total networking power
# -> 50 selfish minors having 9% of total networking power
# ...
# Honest profit: 0.8870967741935479
# Selfish profit: 0.12903225806451613
# Total profit: 1.016129032258064
#
# Running simulation of networking power with:
# -> 50 honest minors having 90% of total networking power
# -> 50 selfish minors having 10% of total networking power
# ...
# Honest profit: 0.8846153846153846
# Selfish profit: 0.11538461538461539
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 89% of total networking power
# -> 50 selfish minors having 11% of total networking power
# ...
# Honest profit: 0.8846153846153847
# Selfish profit: 0.11538461538461539
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 88% of total networking power
# -> 50 selfish minors having 12% of total networking power
# ...
# Honest profit: 0.7551020408163269
# Selfish profit: 0.24489795918367344
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 87% of total networking power
# -> 50 selfish minors having 13% of total networking power
# ...
# Honest profit: 0.9622641509433961
# Selfish profit: 0.03773584905660377
# Total profit: 0.9999999999999999
#
# Running simulation of networking power with:
# -> 50 honest minors having 86% of total networking power
# -> 50 selfish minors having 14% of total networking power
# ...
# Honest profit: 0.8958333333333334
# Selfish profit: 0.10416666666666666
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 85% of total networking power
# -> 50 selfish minors having 15% of total networking power
# ...
# Honest profit: 0.767857142857143
# Selfish profit: 0.2321428571428571
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 84% of total networking power
# -> 50 selfish minors having 16% of total networking power
# ...
# Honest profit: 0.8536585365853662
# Selfish profit: 0.14634146341463417
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 83% of total networking power
# -> 50 selfish minors having 17% of total networking power
# ...
# Honest profit: 0.8000000000000002
# Selfish profit: 0.18181818181818182
# Total profit: 0.9818181818181819
#
# Running simulation of networking power with:
# -> 50 honest minors having 82% of total networking power
# -> 50 selfish minors having 18% of total networking power
# ...
# Honest profit: 0.8518518518518514
# Selfish profit: 0.16666666666666666
# Total profit: 1.0185185185185182
#
# Running simulation of networking power with:
# -> 50 honest minors having 81% of total networking power
# -> 50 selfish minors having 19% of total networking power
# ...
# Honest profit: 0.869565217391304
# Selfish profit: 0.13043478260869565
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 80% of total networking power
# -> 50 selfish minors having 20% of total networking power
# ...
# Honest profit: 0.8571428571428575
# Selfish profit: 0.14285714285714285
# Total profit: 1.0000000000000004
#
# Running simulation of networking power with:
# -> 50 honest minors having 79% of total networking power
# -> 50 selfish minors having 21% of total networking power
# ...
# Honest profit: 0.7884615384615387
# Selfish profit: 0.2115384615384615
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 78% of total networking power
# -> 50 selfish minors having 22% of total networking power
# ...
# Honest profit: 0.8888888888888888
# Selfish profit: 0.1111111111111111
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 77% of total networking power
# -> 50 selfish minors having 23% of total networking power
# ...
# Honest profit: 0.869565217391304
# Selfish profit: 0.13043478260869565
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 76% of total networking power
# -> 50 selfish minors having 24% of total networking power
# ...
# Honest profit: 0.8333333333333328
# Selfish profit: 0.16666666666666666
# Total profit: 0.9999999999999994
#
# Running simulation of networking power with:
# -> 50 honest minors having 75% of total networking power
# -> 50 selfish minors having 25% of total networking power
# ...
# Honest profit: 0.8888888888888886
# Selfish profit: 0.1111111111111111
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 74% of total networking power
# -> 50 selfish minors having 26% of total networking power
# ...
# Honest profit: 0.8571428571428572
# Selfish profit: 0.1607142857142857
# Total profit: 1.0178571428571428
#
# Running simulation of networking power with:
# -> 50 honest minors having 73% of total networking power
# -> 50 selfish minors having 27% of total networking power
# ...
# Honest profit: 0.8392857142857144
# Selfish profit: 0.1607142857142857
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 72% of total networking power
# -> 50 selfish minors having 28% of total networking power
# ...
# Honest profit: 0.894736842105263
# Selfish profit: 0.10526315789473684
# Total profit: 0.9999999999999999
#
# Running simulation of networking power with:
# -> 50 honest minors having 71% of total networking power
# -> 50 selfish minors having 29% of total networking power
# ...
# Honest profit: 0.8269230769230772
# Selfish profit: 0.1730769230769231
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 70% of total networking power
# -> 50 selfish minors having 30% of total networking power
# ...
# Honest profit: 0.7727272727272725
# Selfish profit: 0.2272727272727273
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 69% of total networking power
# -> 50 selfish minors having 31% of total networking power
# ...
# Honest profit: 0.8867924528301886
# Selfish profit: 0.1320754716981132
# Total profit: 1.0188679245283019
#
# Running simulation of networking power with:
# -> 50 honest minors having 68% of total networking power
# -> 50 selfish minors having 32% of total networking power
# ...
# Honest profit: 0.7659574468085106
# Selfish profit: 0.23404255319148937
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 67% of total networking power
# -> 50 selfish minors having 33% of total networking power
# ...
# Honest profit: 0.789473684210527
# Selfish profit: 0.21052631578947367
# Total profit: 1.0000000000000007
#
# Running simulation of networking power with:
# -> 50 honest minors having 66% of total networking power
# -> 50 selfish minors having 34% of total networking power
# ...
# Honest profit: 0.8541666666666665
# Selfish profit: 0.14583333333333331
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 65% of total networking power
# -> 50 selfish minors having 35% of total networking power
# ...
# Honest profit: 0.6808510638297871
# Selfish profit: 0.3191489361702127
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 64% of total networking power
# -> 50 selfish minors having 36% of total networking power
# ...
# Honest profit: 0.8125
# Selfish profit: 0.20833333333333337
# Total profit: 1.0208333333333335
#
# Running simulation of networking power with:
# -> 50 honest minors having 63% of total networking power
# -> 50 selfish minors having 37% of total networking power
# ...
# Honest profit: 0.8333333333333334
# Selfish profit: 0.16666666666666666
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 62% of total networking power
# -> 50 selfish minors having 38% of total networking power
# ...
# Honest profit: 0.8750000000000002
# Selfish profit: 0.12499999999999997
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 61% of total networking power
# -> 50 selfish minors having 39% of total networking power
# ...
# Honest profit: 0.7368421052631582
# Selfish profit: 0.24561403508771928
# Total profit: 0.9824561403508775
#
# Running simulation of networking power with:
# -> 50 honest minors having 60% of total networking power
# -> 50 selfish minors having 40% of total networking power
# ...
# Honest profit: 0.775510204081633
# Selfish profit: 0.22448979591836732
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 59% of total networking power
# -> 50 selfish minors having 41% of total networking power
# ...
# Honest profit: 0.775510204081633
# Selfish profit: 0.22448979591836732
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 58% of total networking power
# -> 50 selfish minors having 42% of total networking power
# ...
# Honest profit: 0.8644067796610168
# Selfish profit: 0.13559322033898305
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 57% of total networking power
# -> 50 selfish minors having 43% of total networking power
# ...
# Honest profit: 0.8113207547169811
# Selfish profit: 0.16981132075471697
# Total profit: 0.981132075471698
#
# Running simulation of networking power with:
# -> 50 honest minors having 56% of total networking power
# -> 50 selfish minors having 44% of total networking power
# ...
# Honest profit: 0.8421052631578947
# Selfish profit: 0.17543859649122806
# Total profit: 1.0175438596491229
#
# Running simulation of networking power with:
# -> 50 honest minors having 55% of total networking power
# -> 50 selfish minors having 45% of total networking power
# ...
# Honest profit: 0.6956521739130432
# Selfish profit: 0.30434782608695643
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 54% of total networking power
# -> 50 selfish minors having 46% of total networking power
# ...
# Honest profit: 0.8035714285714289
# Selfish profit: 0.23214285714285707
# Total profit: 1.035714285714286
#
# Running simulation of networking power with:
# -> 50 honest minors having 53% of total networking power
# -> 50 selfish minors having 47% of total networking power
# ...
# Honest profit: 0.8113207547169811
# Selfish profit: 0.20754716981132074
# Total profit: 1.0188679245283019
#
# Running simulation of networking power with:
# -> 50 honest minors having 52% of total networking power
# -> 50 selfish minors having 48% of total networking power
# ...
# Honest profit: 0.722222222222222
# Selfish profit: 0.2777777777777778
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 51% of total networking power
# -> 50 selfish minors having 49% of total networking power
# ...
# Honest profit: 0.6666666666666666
# Selfish profit: 0.3333333333333333
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 50% of total networking power
# -> 50 selfish minors having 50% of total networking power
# ...
# Honest profit: 0.5555555555555556
# Selfish profit: 0.4222222222222222
# Total profit: 0.9777777777777779
#
# Running simulation of networking power with:
# -> 50 honest minors having 49% of total networking power
# -> 50 selfish minors having 51% of total networking power
# ...
# Honest profit: 0.760869565217391
# Selfish profit: 0.23913043478260865
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 48% of total networking power
# -> 50 selfish minors having 52% of total networking power
# ...
# Honest profit: 0.78125
# Selfish profit: 0.21875
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 47% of total networking power
# -> 50 selfish minors having 53% of total networking power
# ...
# Honest profit: 0.7090909090909092
# Selfish profit: 0.2909090909090909
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 46% of total networking power
# -> 50 selfish minors having 54% of total networking power
# ...
# Honest profit: 0.6739130434782605
# Selfish profit: 0.3478260869565216
# Total profit: 1.0217391304347823
#
# Running simulation of networking power with:
# -> 50 honest minors having 45% of total networking power
# -> 50 selfish minors having 55% of total networking power
# ...
# Honest profit: 0.7454545454545456
# Selfish profit: 0.2545454545454546
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 44% of total networking power
# -> 50 selfish minors having 56% of total networking power
# ...
# Honest profit: 0.7547169811320754
# Selfish profit: 0.2452830188679245
# Total profit: 0.9999999999999999
#
# Running simulation of networking power with:
# -> 50 honest minors having 43% of total networking power
# -> 50 selfish minors having 57% of total networking power
# ...
# Honest profit: 0.6415094339622641
# Selfish profit: 0.3962264150943396
# Total profit: 1.0377358490566038
#
# Running simulation of networking power with:
# -> 50 honest minors having 42% of total networking power
# -> 50 selfish minors having 58% of total networking power
# ...
# Honest profit: 0.6923076923076924
# Selfish profit: 0.3076923076923076
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 41% of total networking power
# -> 50 selfish minors having 59% of total networking power
# ...
# Honest profit: 0.6666666666666667
# Selfish profit: 0.3529411764705881
# Total profit: 1.0196078431372548
#
# Running simulation of networking power with:
# -> 50 honest minors having 40% of total networking power
# -> 50 selfish minors having 60% of total networking power
# ...
# Honest profit: 0.5918367346938778
# Selfish profit: 0.4081632653061225
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 39% of total networking power
# -> 50 selfish minors having 61% of total networking power
# ...
# Honest profit: 0.6600000000000001
# Selfish profit: 0.3199999999999999
# Total profit: 0.98
#
# Running simulation of networking power with:
# -> 50 honest minors having 38% of total networking power
# -> 50 selfish minors having 62% of total networking power
# ...
# Honest profit: 0.6166666666666667
# Selfish profit: 0.36666666666666664
# Total profit: 0.9833333333333334
#
# Running simulation of networking power with:
# -> 50 honest minors having 37% of total networking power
# -> 50 selfish minors having 63% of total networking power
# ...
# Honest profit: 0.7857142857142857
# Selfish profit: 0.21428571428571425
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 36% of total networking power
# -> 50 selfish minors having 64% of total networking power
# ...
# Honest profit: 0.6862745098039217
# Selfish profit: 0.2941176470588235
# Total profit: 0.9803921568627452
#
# Running simulation of networking power with:
# -> 50 honest minors having 35% of total networking power
# -> 50 selfish minors having 65% of total networking power
# ...
# Honest profit: 0.7200000000000003
# Selfish profit: 0.27999999999999997
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 34% of total networking power
# -> 50 selfish minors having 66% of total networking power
# ...
# Honest profit: 0.6250000000000001
# Selfish profit: 0.37499999999999994
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 33% of total networking power
# -> 50 selfish minors having 67% of total networking power
# ...
# Honest profit: 0.6734693877551022
# Selfish profit: 0.326530612244898
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 32% of total networking power
# -> 50 selfish minors having 68% of total networking power
# ...
# Honest profit: 0.5882352941176471
# Selfish profit: 0.4313725490196077
# Total profit: 1.0196078431372548
#
# Running simulation of networking power with:
# -> 50 honest minors having 31% of total networking power
# -> 50 selfish minors having 69% of total networking power
# ...
# Honest profit: 0.6346153846153847
# Selfish profit: 0.3461538461538461
# Total profit: 0.9807692307692308
#
# Running simulation of networking power with:
# -> 50 honest minors having 30% of total networking power
# -> 50 selfish minors having 70% of total networking power
# ...
# Honest profit: 0.6800000000000002
# Selfish profit: 0.31999999999999995
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 29% of total networking power
# -> 50 selfish minors having 71% of total networking power
# ...
# Honest profit: 0.8214285714285717
# Selfish profit: 0.17857142857142855
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 28% of total networking power
# -> 50 selfish minors having 72% of total networking power
# ...
# Honest profit: 0.6981132075471698
# Selfish profit: 0.3018867924528302
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 27% of total networking power
# -> 50 selfish minors having 73% of total networking power
# ...
# Honest profit: 0.6896551724137931
# Selfish profit: 0.3275862068965517
# Total profit: 1.0172413793103448
#
# Running simulation of networking power with:
# -> 50 honest minors having 26% of total networking power
# -> 50 selfish minors having 74% of total networking power
# ...
# Honest profit: 0.7333333333333334
# Selfish profit: 0.24999999999999997
# Total profit: 0.9833333333333334
#
# Running simulation of networking power with:
# -> 50 honest minors having 25% of total networking power
# -> 50 selfish minors having 75% of total networking power
# ...
# Honest profit: 0.5263157894736841
# Selfish profit: 0.4473684210526315
# Total profit: 0.9736842105263156
#
# Running simulation of networking power with:
# -> 50 honest minors having 24% of total networking power
# -> 50 selfish minors having 76% of total networking power
# ...
# Honest profit: 0.7192982456140353
# Selfish profit: 0.2807017543859649
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 23% of total networking power
# -> 50 selfish minors having 77% of total networking power
# ...
# Honest profit: 0.6400000000000001
# Selfish profit: 0.36
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 22% of total networking power
# -> 50 selfish minors having 78% of total networking power
# ...
# Honest profit: 0.7142857142857145
# Selfish profit: 0.2857142857142857
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 21% of total networking power
# -> 50 selfish minors having 79% of total networking power
# ...
# Honest profit: 0.5892857142857142
# Selfish profit: 0.4107142857142856
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 20% of total networking power
# -> 50 selfish minors having 80% of total networking power
# ...
# Honest profit: 0.6923076923076923
# Selfish profit: 0.3269230769230769
# Total profit: 1.0192307692307692
#
# Running simulation of networking power with:
# -> 50 honest minors having 19% of total networking power
# -> 50 selfish minors having 81% of total networking power
# ...
# Honest profit: 0.5918367346938778
# Selfish profit: 0.4081632653061225
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 18% of total networking power
# -> 50 selfish minors having 82% of total networking power
# ...
# Honest profit: 0.7037037037037034
# Selfish profit: 0.31481481481481477
# Total profit: 1.0185185185185182
#
# Running simulation of networking power with:
# -> 50 honest minors having 17% of total networking power
# -> 50 selfish minors having 83% of total networking power
# ...
# Honest profit: 0.6607142857142858
# Selfish profit: 0.3214285714285714
# Total profit: 0.9821428571428572
#
# Running simulation of networking power with:
# -> 50 honest minors having 16% of total networking power
# -> 50 selfish minors having 84% of total networking power
# ...
# Honest profit: 0.5416666666666666
# Selfish profit: 0.4375
# Total profit: 0.9791666666666666
#
# Running simulation of networking power with:
# -> 50 honest minors having 15% of total networking power
# -> 50 selfish minors having 85% of total networking power
# ...
# Honest profit: 0.625
# Selfish profit: 0.3749999999999999
# Total profit: 0.9999999999999999
#
# Running simulation of networking power with:
# -> 50 honest minors having 14% of total networking power
# -> 50 selfish minors having 86% of total networking power
# ...
# Honest profit: 0.6800000000000003
# Selfish profit: 0.32
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 13% of total networking power
# -> 50 selfish minors having 87% of total networking power
# ...
# Honest profit: 0.4999999999999999
# Selfish profit: 0.49999999999999994
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 12% of total networking power
# -> 50 selfish minors having 88% of total networking power
# ...
# Honest profit: 0.5111111111111111
# Selfish profit: 0.5111111111111111
# Total profit: 1.0222222222222221
#
# Running simulation of networking power with:
# -> 50 honest minors having 11% of total networking power
# -> 50 selfish minors having 89% of total networking power
# ...
# Honest profit: 0.6037735849056604
# Selfish profit: 0.3962264150943396
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 10% of total networking power
# -> 50 selfish minors having 90% of total networking power
# ...
# Honest profit: 0.6545454545454547
# Selfish profit: 0.34545454545454546
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 9% of total networking power
# -> 50 selfish minors having 91% of total networking power
# ...
# Honest profit: 0.5652173913043477
# Selfish profit: 0.43478260869565205
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 8% of total networking power
# -> 50 selfish minors having 92% of total networking power
# ...
# Honest profit: 0.5769230769230769
# Selfish profit: 0.423076923076923
# Total profit: 0.9999999999999999
#
# Running simulation of networking power with:
# -> 50 honest minors having 7% of total networking power
# -> 50 selfish minors having 93% of total networking power
# ...
# Honest profit: 0.6333333333333334
# Selfish profit: 0.36666666666666664
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 6% of total networking power
# -> 50 selfish minors having 94% of total networking power
# ...
# Honest profit: 0.5869565217391303
# Selfish profit: 0.4130434782608694
# Total profit: 0.9999999999999997
#
# Running simulation of networking power with:
# -> 50 honest minors having 5% of total networking power
# -> 50 selfish minors having 95% of total networking power
# ...
# Honest profit: 0.5416666666666666
# Selfish profit: 0.4791666666666666
# Total profit: 1.0208333333333333
#
# Running simulation of networking power with:
# -> 50 honest minors having 4% of total networking power
# -> 50 selfish minors having 96% of total networking power
# ...
# Honest profit: 0.5918367346938777
# Selfish profit: 0.4081632653061225
# Total profit: 1.0000000000000002
#
# Running simulation of networking power with:
# -> 50 honest minors having 3% of total networking power
# -> 50 selfish minors having 97% of total networking power
# ...
# Honest profit: 0.6833333333333335
# Selfish profit: 0.31666666666666665
# Total profit: 1.0
#
# Running simulation of networking power with:
# -> 50 honest minors having 2% of total networking power
# -> 50 selfish minors having 98% of total networking power
# ...
# Honest profit: 0.5892857142857142
# Selfish profit: 0.4107142857142856
# Total profit: 0.9999999999999998
#
# Running simulation of networking power with:
# -> 50 honest minors having 1% of total networking power
# -> 50 selfish minors having 99% of total networking power
# ...
# Honest profit: 0.6071428571428571
# Selfish profit: 0.39285714285714274
# Total profit: 0.9999999999999998

# %%
import matplotlib.pyplot as plt

selfish_power = list(sim_range_selfish)
honest_power = list(sim_range_honest)

fig, axs = plt.subplots(1, 2, figsize=(15,5))

axs[0].plot(honest_power, selfish_profits, label = "selfish mining")
axs[0].plot(honest_power, honest_profits, label = "honest mining")
axs[0].tick_params(axis='x', colors='red')
axs[0].tick_params(axis='y', colors='red')
axs[0].set_xlabel('Honest Network Power').set_color('red')
axs[0].set_ylabel('Persentage of Mined Blocks (Profit)').set_color('red')
axs[0].legend()

axs[1].plot(selfish_power, selfish_profits, label = "selfish mining")
axs[1].plot(selfish_power, honest_profits, label = "honest mining")
axs[1].tick_params(axis='x', colors='red')
axs[1].tick_params(axis='y', colors='red')
axs[1].set_xlabel('Selfish Network Power').set_color('red')
axs[1].set_ylabel('Persentage of Mined Blocks (Profit)').set_color('red')
axs[1].legend()

# %% [markdown]
# You may want to address some of the limitations though:
#
# 1- What if we have more than 1 correct fork (For example we have 3 blocks as the max height, 1 for selfish, 2 for others).
# -> all blocks will still have some chances of being selected, but the type of the block creator with higher networking power have higher chances as we pick a random number from 1 to 100 and if this random number is smaller or equal than the networking power of the miner then the blocks created by miners who shares his type is selected, if not than the other blocks is selected, the type can be either selfish mined blocks or honest mined blocks.
#
# 2- What if we have more than 1 selfish miners with different networking power?
# 3- Can we have different networking power for all miners?
# 4- Have some other diagrams for showing the impact of both network and mining power

# %%
# 2- What if we have more than 1 selfish miners with different networking power?
# 3- Can we have different networking power for all miners?

def make_miners_with_varying_network_power(type_of_minors, total_network_power, num_of_miners, total_mining_power, blockchain):
    miners = []
    remaining_mining_power = total_mining_power
    
    remaining_network_power = total_network_power
    
    while remaining_mining_power > 0:
        if len(miners) == num_of_miners-1:
            mining_power = remaining_mining_power
            network_power = remaining_network_power
        else:
            mining_power = round(total_mining_power/num_of_miners)
            
            if remaining_network_power != 0:
                possible_network_power = list(range(1, remaining_network_power+1, 1))
                network_power = random.choice(possible_network_power)
                remaining_network_power -= network_power
            else:
                network_power = 0
        
        if type_of_minors == "honest":
            miner = Miner(mining_power, network_power, "Honest", f"Honest miner nr. {len(miners)+1}", blockchain)
        elif type_of_minors == "selfish":
            miner = SelfishMiner(mining_power, network_power, "Selfish", f"Selfish miner nr. {len(miners)+1}", blockchain)
        
        miners.append(miner)
        remaining_mining_power -= mining_power
        
    return miners

output = True
selfish_profits = []
honest_profits = []
sim_range_selfish = range(0, 100, 1)
sim_range_honest = range(100, 0, -1)

print("Simulating varying network power between miners with")
print("-> equal mining power for each miner")
print("-> and varying the number of honest and selfish miners at each simulation")
print("")

for i in sim_range_selfish:
    num_of_selfish_miners = i
    num_of_honest_miners = 100-i
    
    total_mining_power = 100
    honest_mining_power_share = round(num_of_honest_miners/total_mining_power, 2)
    selfish_mining_power_share = round(num_of_selfish_miners/total_mining_power, 2)
    honest_mining_power = round(total_mining_power * honest_mining_power_share)
    selfish_mining_power = round(total_mining_power * selfish_mining_power_share)
    
    total_network_power = 100
    honest_network_power_share = round(num_of_honest_miners/total_network_power, 2)
    selfish_network_power_share = round(num_of_selfish_miners/total_network_power, 2)
    honest_network_power = round(total_network_power * honest_network_power_share)
    selfish_network_power = round(total_network_power * selfish_network_power_share)

    bc = Blockchain("0" , 11)
    
    honest_miners = make_miners_with_varying_network_power("honest", honest_network_power, num_of_honest_miners, honest_mining_power, bc)
    
    selfish_miners = make_miners_with_varying_network_power("selfish", selfish_network_power, num_of_selfish_miners, selfish_mining_power, bc)
        
    if output:
        print(f"Running simulation with:")
        print(f"-> {len(honest_miners)} honest minors having {honest_network_power}% of total networking power and {honest_mining_power}% of total mining power")
        print(f"-> {len(selfish_miners)} selfish minors having {selfish_network_power}% of total networking power and {selfish_mining_power}% of total mining power")
        print("...")
        
    selfish_profit, honest_profit = simulate_selfish_mining(bc, honest_miners, selfish_miners)
    selfish_profits.append(selfish_profit)
    honest_profits.append(honest_profit)
    
    if output:
        print(f"Honest profit: {honest_profit}")
        print(f"Selfish profit: {selfish_profit}")
        print(f"Total profit: {round(selfish_profit+honest_profit)}")
        print()
# Out:
# Simulating varying network power between miners with
# -> equal mining power for each miner
# -> and varying the number of honest and selfish miners at each simulation
#
# Running simulation with:
# -> 100 honest minors having 100% of total networking power and 100% of total mining power
# -> 0 selfish minors having 0% of total networking power and 0% of total mining power
# ...
# Honest profit: 1.0000000000000004
# Selfish profit: 0
# Total profit: 1
#
# Running simulation with:
# -> 99 honest minors having 99% of total networking power and 99% of total mining power
# -> 1 selfish minors having 1% of total networking power and 1% of total mining power
# ...
# Honest profit: 1.0000000000000002
# Selfish profit: 0.0
# Total profit: 1
#
# Running simulation with:
# -> 98 honest minors having 98% of total networking power and 98% of total mining power
# -> 2 selfish minors having 2% of total networking power and 2% of total mining power
# ...
# Honest profit: 0.979797979797979
# Selfish profit: 0.020202020202020204
# Total profit: 1
#
# Running simulation with:
# -> 97 honest minors having 97% of total networking power and 97% of total mining power
# -> 3 selfish minors having 3% of total networking power and 3% of total mining power
# ...
# Honest profit: 1.0000000000000007
# Selfish profit: 0.0
# Total profit: 1
#
# Running simulation with:
# -> 96 honest minors having 96% of total networking power and 96% of total mining power
# -> 4 selfish minors having 4% of total networking power and 4% of total mining power
# ...
# Honest profit: 0.9687499999999997
# Selfish profit: 0.03125
# Total profit: 1
#
# Running simulation with:
# -> 95 honest minors having 95% of total networking power and 95% of total mining power
# -> 5 selfish minors having 5% of total networking power and 5% of total mining power
# ...
# Honest profit: 0.9791666666666662
# Selfish profit: 0.020833333333333332
# Total profit: 1
#
# Running simulation with:
# -> 94 honest minors having 94% of total networking power and 94% of total mining power
# -> 6 selfish minors having 6% of total networking power and 6% of total mining power
# ...
# Honest profit: 0.968421052631579
# Selfish profit: 0.031578947368421054
# Total profit: 1
#
# Running simulation with:
# -> 93 honest minors having 93% of total networking power and 93% of total mining power
# -> 7 selfish minors having 7% of total networking power and 7% of total mining power
# ...
# Honest profit: 0.9468085106382974
# Selfish profit: 0.05319148936170213
# Total profit: 1
#
# Running simulation with:
# -> 92 honest minors having 92% of total networking power and 92% of total mining power
# -> 8 selfish minors having 8% of total networking power and 8% of total mining power
# ...
# Honest profit: 0.9325842696629221
# Selfish profit: 0.06741573033707865
# Total profit: 1
#
# Running simulation with:
# -> 91 honest minors having 91% of total networking power and 91% of total mining power
# -> 9 selfish minors having 9% of total networking power and 9% of total mining power
# ...
# Honest profit: 0.9565217391304354
# Selfish profit: 0.043478260869565216
# Total profit: 1
#
# Running simulation with:
# -> 90 honest minors having 90% of total networking power and 90% of total mining power
# -> 10 selfish minors having 10% of total networking power and 10% of total mining power
# ...
# Honest profit: 0.8571428571428567
# Selfish profit: 0.14285714285714285
# Total profit: 1
#
# Running simulation with:
# -> 89 honest minors having 89% of total networking power and 89% of total mining power
# -> 11 selfish minors having 11% of total networking power and 11% of total mining power
# ...
# Honest profit: 0.848837209302326
# Selfish profit: 0.1511627906976744
# Total profit: 1
#
# Running simulation with:
# -> 88 honest minors having 88% of total networking power and 88% of total mining power
# -> 12 selfish minors having 12% of total networking power and 12% of total mining power
# ...
# Honest profit: 0.9222222222222219
# Selfish profit: 0.07777777777777778
# Total profit: 1
#
# Running simulation with:
# -> 87 honest minors having 87% of total networking power and 87% of total mining power
# -> 13 selfish minors having 13% of total networking power and 13% of total mining power
# ...
# Honest profit: 0.8170731707317078
# Selfish profit: 0.17073170731707316
# Total profit: 1
#
# Running simulation with:
# -> 86 honest minors having 86% of total networking power and 86% of total mining power
# -> 14 selfish minors having 14% of total networking power and 14% of total mining power
# ...
# Honest profit: 0.9204545454545449
# Selfish profit: 0.07954545454545456
# Total profit: 1
#
# Running simulation with:
# -> 85 honest minors having 85% of total networking power and 85% of total mining power
# -> 15 selfish minors having 15% of total networking power and 15% of total mining power
# ...
# Honest profit: 0.8249999999999997
# Selfish profit: 0.175
# Total profit: 1
#
# Running simulation with:
# -> 84 honest minors having 84% of total networking power and 84% of total mining power
# -> 16 selfish minors having 16% of total networking power and 16% of total mining power
# ...
# Honest profit: 0.8026315789473686
# Selfish profit: 0.19736842105263158
# Total profit: 1
#
# Running simulation with:
# -> 83 honest minors having 83% of total networking power and 83% of total mining power
# -> 17 selfish minors having 17% of total networking power and 17% of total mining power
# ...
# Honest profit: 0.906976744186047
# Selfish profit: 0.09302325581395349
# Total profit: 1
#
# Running simulation with:
# -> 82 honest minors having 82% of total networking power and 82% of total mining power
# -> 18 selfish minors having 18% of total networking power and 18% of total mining power
# ...
# Honest profit: 0.8571428571428568
# Selfish profit: 0.14285714285714285
# Total profit: 1
#
# Running simulation with:
# -> 81 honest minors having 81% of total networking power and 81% of total mining power
# -> 19 selfish minors having 19% of total networking power and 19% of total mining power
# ...
# Honest profit: 0.845238095238095
# Selfish profit: 0.14285714285714285
# Total profit: 1
#
# Running simulation with:
# -> 80 honest minors having 80% of total networking power and 80% of total mining power
# -> 20 selfish minors having 20% of total networking power and 20% of total mining power
# ...
# Honest profit: 0.8780487804878053
# Selfish profit: 0.12195121951219512
# Total profit: 1
#
# Running simulation with:
# -> 79 honest minors having 79% of total networking power and 79% of total mining power
# -> 21 selfish minors having 21% of total networking power and 21% of total mining power
# ...
# Honest profit: 0.8421052631578951
# Selfish profit: 0.15789473684210525
# Total profit: 1
#
# Running simulation with:
# -> 78 honest minors having 78% of total networking power and 78% of total mining power
# -> 22 selfish minors having 22% of total networking power and 22% of total mining power
# ...
# Honest profit: 0.7922077922077924
# Selfish profit: 0.19480519480519484
# Total profit: 1
#
# Running simulation with:
# -> 77 honest minors having 77% of total networking power and 77% of total mining power
# -> 23 selfish minors having 23% of total networking power and 23% of total mining power
# ...
# Honest profit: 0.7948717948717945
# Selfish profit: 0.20512820512820512
# Total profit: 1
#
# Running simulation with:
# -> 76 honest minors having 76% of total networking power and 76% of total mining power
# -> 24 selfish minors having 24% of total networking power and 24% of total mining power
# ...
# Honest profit: 0.8266666666666659
# Selfish profit: 0.17333333333333334
# Total profit: 1
#
# Running simulation with:
# -> 75 honest minors having 75% of total networking power and 75% of total mining power
# -> 25 selfish minors having 25% of total networking power and 25% of total mining power
# ...
# Honest profit: 0.7702702702702697
# Selfish profit: 0.21621621621621623
# Total profit: 1
#
# Running simulation with:
# -> 74 honest minors having 74% of total networking power and 74% of total mining power
# -> 26 selfish minors having 26% of total networking power and 26% of total mining power
# ...
# Honest profit: 0.7777777777777771
# Selfish profit: 0.20833333333333334
# Total profit: 1
#
# Running simulation with:
# -> 73 honest minors having 73% of total networking power and 73% of total mining power
# -> 27 selfish minors having 27% of total networking power and 27% of total mining power
# ...
# Honest profit: 0.7638888888888886
# Selfish profit: 0.22222222222222227
# Total profit: 1
#
# Running simulation with:
# -> 72 honest minors having 72% of total networking power and 72% of total mining power
# -> 28 selfish minors having 28% of total networking power and 28% of total mining power
# ...
# Honest profit: 0.7746478873239433
# Selfish profit: 0.22535211267605637
# Total profit: 1
#
# Running simulation with:
# -> 71 honest minors having 71% of total networking power and 71% of total mining power
# -> 29 selfish minors having 29% of total networking power and 29% of total mining power
# ...
# Honest profit: 0.8026315789473685
# Selfish profit: 0.18421052631578946
# Total profit: 1
#
# Running simulation with:
# -> 70 honest minors having 70% of total networking power and 70% of total mining power
# -> 30 selfish minors having 30% of total networking power and 30% of total mining power
# ...
# Honest profit: 0.7826086956521736
# Selfish profit: 0.2028985507246377
# Total profit: 1
#
# Running simulation with:
# -> 69 honest minors having 69% of total networking power and 69% of total mining power
# -> 31 selfish minors having 31% of total networking power and 31% of total mining power
# ...
# Honest profit: 0.7571428571428568
# Selfish profit: 0.22857142857142862
# Total profit: 1
#
# Running simulation with:
# -> 68 honest minors having 68% of total networking power and 68% of total mining power
# -> 32 selfish minors having 32% of total networking power and 32% of total mining power
# ...
# Honest profit: 0.7681159420289855
# Selfish profit: 0.21739130434782608
# Total profit: 1
#
# Running simulation with:
# -> 67 honest minors having 67% of total networking power and 67% of total mining power
# -> 33 selfish minors having 33% of total networking power and 33% of total mining power
# ...
# Honest profit: 0.7464788732394361
# Selfish profit: 0.23943661971830987
# Total profit: 1
#
# Running simulation with:
# -> 66 honest minors having 66% of total networking power and 66% of total mining power
# -> 34 selfish minors having 34% of total networking power and 34% of total mining power
# ...
# Honest profit: 0.6805555555555554
# Selfish profit: 0.30555555555555564
# Total profit: 1
#
# Running simulation with:
# -> 65 honest minors having 65% of total networking power and 65% of total mining power
# -> 35 selfish minors having 35% of total networking power and 35% of total mining power
# ...
# Honest profit: 0.7377049180327871
# Selfish profit: 0.2622950819672131
# Total profit: 1
#
# Running simulation with:
# -> 64 honest minors having 64% of total networking power and 64% of total mining power
# -> 36 selfish minors having 36% of total networking power and 36% of total mining power
# ...
# Honest profit: 0.7258064516129029
# Selfish profit: 0.27419354838709664
# Total profit: 1
#
# Running simulation with:
# -> 63 honest minors having 63% of total networking power and 63% of total mining power
# -> 37 selfish minors having 37% of total networking power and 37% of total mining power
# ...
# Honest profit: 0.7704918032786889
# Selfish profit: 0.22950819672131148
# Total profit: 1
#
# Running simulation with:
# -> 62 honest minors having 62% of total networking power and 62% of total mining power
# -> 38 selfish minors having 38% of total networking power and 38% of total mining power
# ...
# Honest profit: 0.7118644067796609
# Selfish profit: 0.28813559322033905
# Total profit: 1
#
# Running simulation with:
# -> 61 honest minors having 61% of total networking power and 61% of total mining power
# -> 39 selfish minors having 39% of total networking power and 39% of total mining power
# ...
# Honest profit: 0.7499999999999998
# Selfish profit: 0.23611111111111116
# Total profit: 1
#
# Running simulation with:
# -> 60 honest minors having 60% of total networking power and 60% of total mining power
# -> 40 selfish minors having 40% of total networking power and 40% of total mining power
# ...
# Honest profit: 0.6666666666666667
# Selfish profit: 0.31746031746031744
# Total profit: 1
#
# Running simulation with:
# -> 59 honest minors having 59% of total networking power and 59% of total mining power
# -> 41 selfish minors having 41% of total networking power and 41% of total mining power
# ...
# Honest profit: 0.6825396825396821
# Selfish profit: 0.30158730158730157
# Total profit: 1
#
# Running simulation with:
# -> 58 honest minors having 58% of total networking power and 58% of total mining power
# -> 42 selfish minors having 42% of total networking power and 42% of total mining power
# ...
# Honest profit: 0.732142857142857
# Selfish profit: 0.2678571428571428
# Total profit: 1
#
# Running simulation with:
# -> 57 honest minors having 57% of total networking power and 57% of total mining power
# -> 43 selfish minors having 43% of total networking power and 43% of total mining power
# ...
# Honest profit: 0.7384615384615383
# Selfish profit: 0.26153846153846155
# Total profit: 1
#
# Running simulation with:
# -> 56 honest minors having 56% of total networking power and 56% of total mining power
# -> 44 selfish minors having 44% of total networking power and 44% of total mining power
# ...
# Honest profit: 0.6779661016949149
# Selfish profit: 0.3050847457627119
# Total profit: 1
#
# Running simulation with:
# -> 55 honest minors having 55% of total networking power and 55% of total mining power
# -> 45 selfish minors having 45% of total networking power and 45% of total mining power
# ...
# Honest profit: 0.6727272727272728
# Selfish profit: 0.3272727272727273
# Total profit: 1
#
# Running simulation with:
# -> 54 honest minors having 54% of total networking power and 54% of total mining power
# -> 46 selfish minors having 46% of total networking power and 46% of total mining power
# ...
# Honest profit: 0.6935483870967739
# Selfish profit: 0.30645161290322576
# Total profit: 1
#
# Running simulation with:
# -> 53 honest minors having 53% of total networking power and 53% of total mining power
# -> 47 selfish minors having 47% of total networking power and 47% of total mining power
# ...
# Honest profit: 0.7192982456140351
# Selfish profit: 0.2631578947368421
# Total profit: 1
#
# Running simulation with:
# -> 52 honest minors having 52% of total networking power and 52% of total mining power
# -> 48 selfish minors having 48% of total networking power and 48% of total mining power
# ...
# Honest profit: 0.706896551724138
# Selfish profit: 0.27586206896551724
# Total profit: 1
#
# Running simulation with:
# -> 51 honest minors having 51% of total networking power and 51% of total mining power
# -> 49 selfish minors having 49% of total networking power and 49% of total mining power
# ...
# Honest profit: 0.6600000000000001
# Selfish profit: 0.32000000000000006
# Total profit: 1
#
# Running simulation with:
# -> 50 honest minors having 50% of total networking power and 50% of total mining power
# -> 50 selfish minors having 50% of total networking power and 50% of total mining power
# ...
# Honest profit: 0.660377358490566
# Selfish profit: 0.32075471698113206
# Total profit: 1
#
# Running simulation with:
# -> 49 honest minors having 49% of total networking power and 49% of total mining power
# -> 51 selfish minors having 51% of total networking power and 51% of total mining power
# ...
# Honest profit: 0.685185185185185
# Selfish profit: 0.31481481481481477
# Total profit: 1
#
# Running simulation with:
# -> 48 honest minors having 48% of total networking power and 48% of total mining power
# -> 52 selfish minors having 52% of total networking power and 52% of total mining power
# ...
# Honest profit: 0.6666666666666667
# Selfish profit: 0.33333333333333337
# Total profit: 1
#
# Running simulation with:
# -> 47 honest minors having 47% of total networking power and 47% of total mining power
# -> 53 selfish minors having 53% of total networking power and 53% of total mining power
# ...
# Honest profit: 0.6041666666666667
# Selfish profit: 0.39583333333333326
# Total profit: 1
#
# Running simulation with:
# -> 46 honest minors having 46% of total networking power and 46% of total mining power
# -> 54 selfish minors having 54% of total networking power and 54% of total mining power
# ...
# Honest profit: 0.5918367346938777
# Selfish profit: 0.38775510204081637
# Total profit: 1
#
# Running simulation with:
# -> 45 honest minors having 45% of total networking power and 45% of total mining power
# -> 55 selfish minors having 55% of total networking power and 55% of total mining power
# ...
# Honest profit: 0.5227272727272726
# Selfish profit: 0.45454545454545453
# Total profit: 1
#
# Running simulation with:
# -> 44 honest minors having 44% of total networking power and 44% of total mining power
# -> 56 selfish minors having 56% of total networking power and 56% of total mining power
# ...
# Honest profit: 0.5217391304347824
# Selfish profit: 0.4565217391304347
# Total profit: 1
#
# Running simulation with:
# -> 43 honest minors having 43% of total networking power and 43% of total mining power
# -> 57 selfish minors having 57% of total networking power and 57% of total mining power
# ...
# Honest profit: 0.5714285714285715
# Selfish profit: 0.42857142857142866
# Total profit: 1
#
# Running simulation with:
# -> 42 honest minors having 42% of total networking power and 42% of total mining power
# -> 58 selfish minors having 58% of total networking power and 58% of total mining power
# ...
# Honest profit: 0.6964285714285714
# Selfish profit: 0.28571428571428564
# Total profit: 1
#
# Running simulation with:
# -> 41 honest minors having 41% of total networking power and 41% of total mining power
# -> 59 selfish minors having 59% of total networking power and 59% of total mining power
# ...
# Honest profit: 0.6250000000000002
# Selfish profit: 0.3749999999999999
# Total profit: 1
#
# Running simulation with:
# -> 40 honest minors having 40% of total networking power and 40% of total mining power
# -> 60 selfish minors having 60% of total networking power and 60% of total mining power
# ...
# Honest profit: 0.4772727272727273
# Selfish profit: 0.5
# Total profit: 1
#
# Running simulation with:
# -> 39 honest minors having 39% of total networking power and 39% of total mining power
# -> 61 selfish minors having 61% of total networking power and 61% of total mining power
# ...
# Honest profit: 0.5833333333333335
# Selfish profit: 0.38888888888888895
# Total profit: 1
#
# Running simulation with:
# -> 38 honest minors having 38% of total networking power and 38% of total mining power
# -> 62 selfish minors having 62% of total networking power and 62% of total mining power
# ...
# Honest profit: 0.608695652173913
# Selfish profit: 0.3695652173913042
# Total profit: 1
#
# Running simulation with:
# -> 37 honest minors having 37% of total networking power and 37% of total mining power
# -> 63 selfish minors having 63% of total networking power and 63% of total mining power
# ...
# Honest profit: 0.6511627906976744
# Selfish profit: 0.34883720930232553
# Total profit: 1
#
# Running simulation with:
# -> 36 honest minors having 36% of total networking power and 36% of total mining power
# -> 64 selfish minors having 64% of total networking power and 64% of total mining power
# ...
# Honest profit: 0.6304347826086955
# Selfish profit: 0.34782608695652173
# Total profit: 1
#
# Running simulation with:
# -> 35 honest minors having 35% of total networking power and 35% of total mining power
# -> 65 selfish minors having 65% of total networking power and 65% of total mining power
# ...
# Honest profit: 0.3823529411764706
# Selfish profit: 0.5882352941176471
# Total profit: 1
#
# Running simulation with:
# -> 34 honest minors having 34% of total networking power and 34% of total mining power
# -> 66 selfish minors having 66% of total networking power and 66% of total mining power
# ...
# Honest profit: 0.5918367346938775
# Selfish profit: 0.3877551020408163
# Total profit: 1
#
# Running simulation with:
# -> 33 honest minors having 33% of total networking power and 33% of total mining power
# -> 67 selfish minors having 67% of total networking power and 67% of total mining power
# ...
# Honest profit: 0.4375
# Selfish profit: 0.5625
# Total profit: 1
#
# Running simulation with:
# -> 32 honest minors having 32% of total networking power and 32% of total mining power
# -> 68 selfish minors having 68% of total networking power and 68% of total mining power
# ...
# Honest profit: 0.4285714285714286
# Selfish profit: 0.5714285714285715
# Total profit: 1
#
# Running simulation with:
# -> 31 honest minors having 31% of total networking power and 31% of total mining power
# -> 69 selfish minors having 69% of total networking power and 69% of total mining power
# ...
# Honest profit: 0.5
# Selfish profit: 0.5250000000000002
# Total profit: 1
#
# Running simulation with:
# -> 30 honest minors having 30% of total networking power and 30% of total mining power
# -> 70 selfish minors having 70% of total networking power and 70% of total mining power
# ...
# Honest profit: 0.53125
# Selfish profit: 0.46875
# Total profit: 1
#
# Running simulation with:
# -> 29 honest minors having 29% of total networking power and 29% of total mining power
# -> 71 selfish minors having 71% of total networking power and 71% of total mining power
# ...
# Honest profit: 0.5454545454545454
# Selfish profit: 0.4242424242424242
# Total profit: 1
#
# Running simulation with:
# -> 28 honest minors having 28% of total networking power and 28% of total mining power
# -> 72 selfish minors having 72% of total networking power and 72% of total mining power
# ...
# Honest profit: 0.5135135135135136
# Selfish profit: 0.4864864864864865
# Total profit: 1
#
# Running simulation with:
# -> 27 honest minors having 27% of total networking power and 27% of total mining power
# -> 73 selfish minors having 73% of total networking power and 73% of total mining power
# ...
# Honest profit: 0.5250000000000001
# Selfish profit: 0.45000000000000007
# Total profit: 1
#
# Running simulation with:
# -> 26 honest minors having 26% of total networking power and 26% of total mining power
# -> 74 selfish minors having 74% of total networking power and 74% of total mining power
# ...
# Honest profit: 0.5151515151515151
# Selfish profit: 0.48484848484848475
# Total profit: 1
#
# Running simulation with:
# -> 25 honest minors having 25% of total networking power and 25% of total mining power
# -> 75 selfish minors having 75% of total networking power and 75% of total mining power
# ...
# Honest profit: 0.6052631578947366
# Selfish profit: 0.3684210526315789
# Total profit: 1
#
# Running simulation with:
# -> 24 honest minors having 24% of total networking power and 24% of total mining power
# -> 76 selfish minors having 76% of total networking power and 76% of total mining power
# ...
# Honest profit: 0.5666666666666667
# Selfish profit: 0.43333333333333335
# Total profit: 1
#
# Running simulation with:
# -> 23 honest minors having 23% of total networking power and 23% of total mining power
# -> 77 selfish minors having 77% of total networking power and 77% of total mining power
# ...
# Honest profit: 0.4285714285714285
# Selfish profit: 0.5357142857142856
# Total profit: 1
#
# Running simulation with:
# -> 22 honest minors having 22% of total networking power and 22% of total mining power
# -> 78 selfish minors having 78% of total networking power and 78% of total mining power
# ...
# Honest profit: 0.3333333333333333
# Selfish profit: 0.6333333333333333
# Total profit: 1
#
# Running simulation with:
# -> 21 honest minors having 21% of total networking power and 21% of total mining power
# -> 79 selfish minors having 79% of total networking power and 79% of total mining power
# ...
# Honest profit: 0.4166666666666667
# Selfish profit: 0.5416666666666666
# Total profit: 1
#
# Running simulation with:
# -> 20 honest minors having 20% of total networking power and 20% of total mining power
# -> 80 selfish minors having 80% of total networking power and 80% of total mining power
# ...
# Honest profit: 0.40625
# Selfish profit: 0.59375
# Total profit: 1
#
# Running simulation with:
# -> 19 honest minors having 19% of total networking power and 19% of total mining power
# -> 81 selfish minors having 81% of total networking power and 81% of total mining power
# ...
# Honest profit: 0.36666666666666664
# Selfish profit: 0.6
# Total profit: 1
#
# Running simulation with:
# -> 18 honest minors having 18% of total networking power and 18% of total mining power
# -> 82 selfish minors having 82% of total networking power and 82% of total mining power
# ...
# Honest profit: 0.2692307692307693
# Selfish profit: 0.7307692307692306
# Total profit: 1
#
# Running simulation with:
# -> 17 honest minors having 17% of total networking power and 17% of total mining power
# -> 83 selfish minors having 83% of total networking power and 83% of total mining power
# ...
# Honest profit: 0.44
# Selfish profit: 0.52
# Total profit: 1
#
# Running simulation with:
# -> 16 honest minors having 16% of total networking power and 16% of total mining power
# -> 84 selfish minors having 84% of total networking power and 84% of total mining power
# ...
# Honest profit: 0.3076923076923077
# Selfish profit: 0.6923076923076923
# Total profit: 1
#
# Running simulation with:
# -> 15 honest minors having 15% of total networking power and 15% of total mining power
# -> 85 selfish minors having 85% of total networking power and 85% of total mining power
# ...
# Honest profit: 0.3571428571428571
# Selfish profit: 0.6428571428571427
# Total profit: 1
#
# Running simulation with:
# -> 14 honest minors having 14% of total networking power and 14% of total mining power
# -> 86 selfish minors having 86% of total networking power and 86% of total mining power
# ...
# Honest profit: 0.3225806451612903
# Selfish profit: 0.7096774193548385
# Total profit: 1
#
# Running simulation with:
# -> 13 honest minors having 13% of total networking power and 13% of total mining power
# -> 87 selfish minors having 87% of total networking power and 87% of total mining power
# ...
# Honest profit: 0.2692307692307693
# Selfish profit: 0.7307692307692306
# Total profit: 1
#
# Running simulation with:
# -> 12 honest minors having 12% of total networking power and 12% of total mining power
# -> 88 selfish minors having 88% of total networking power and 88% of total mining power
# ...
# Honest profit: 0.25
# Selfish profit: 0.75
# Total profit: 1
#
# Running simulation with:
# -> 11 honest minors having 11% of total networking power and 11% of total mining power
# -> 89 selfish minors having 89% of total networking power and 89% of total mining power
# ...
# Honest profit: 0.2222222222222222
# Selfish profit: 0.7222222222222223
# Total profit: 1
#
# Running simulation with:
# -> 10 honest minors having 10% of total networking power and 10% of total mining power
# -> 90 selfish minors having 90% of total networking power and 90% of total mining power
# ...
# Honest profit: 0.3157894736842105
# Selfish profit: 0.6842105263157895
# Total profit: 1
#
# Running simulation with:
# -> 9 honest minors having 9% of total networking power and 9% of total mining power
# -> 91 selfish minors having 91% of total networking power and 91% of total mining power
# ...
# Honest profit: 0.2631578947368421
# Selfish profit: 0.6842105263157895
# Total profit: 1
#
# Running simulation with:
# -> 8 honest minors having 8% of total networking power and 8% of total mining power
# -> 92 selfish minors having 92% of total networking power and 92% of total mining power
# ...
# Honest profit: 0.375
# Selfish profit: 0.6875
# Total profit: 1
#
# Running simulation with:
# -> 7 honest minors having 7% of total networking power and 7% of total mining power
# -> 93 selfish minors having 93% of total networking power and 93% of total mining power
# ...
# Honest profit: 0.2608695652173913
# Selfish profit: 0.7391304347826086
# Total profit: 1
#
# Running simulation with:
# -> 6 honest minors having 6% of total networking power and 6% of total mining power
# -> 94 selfish minors having 94% of total networking power and 94% of total mining power
# ...
# Honest profit: 0.2222222222222222
# Selfish profit: 0.7222222222222221
# Total profit: 1
#
# Running simulation with:
# -> 5 honest minors having 5% of total networking power and 5% of total mining power
# -> 95 selfish minors having 95% of total networking power and 95% of total mining power
# ...
# Honest profit: 0.20833333333333331
# Selfish profit: 0.7916666666666666
# Total profit: 1
#
# Running simulation with:
# -> 4 honest minors having 4% of total networking power and 4% of total mining power
# -> 96 selfish minors having 96% of total networking power and 96% of total mining power
# ...
# Honest profit: 0.045454545454545456
# Selfish profit: 0.9545454545454546
# Total profit: 1
#
# Running simulation with:
# -> 3 honest minors having 3% of total networking power and 3% of total mining power
# -> 97 selfish minors having 97% of total networking power and 97% of total mining power
# ...
# Honest profit: 0.0
# Selfish profit: 0.9444444444444444
# Total profit: 1
#
# Running simulation with:
# -> 2 honest minors having 2% of total networking power and 2% of total mining power
# -> 98 selfish minors having 98% of total networking power and 98% of total mining power
# ...
# Honest profit: 0.045454545454545456
# Selfish profit: 0.9545454545454546
# Total profit: 1
#
# Running simulation with:
# -> 1 honest minors having 1% of total networking power and 1% of total mining power
# -> 99 selfish minors having 99% of total networking power and 99% of total mining power
# ...
# Honest profit: 0.125
# Selfish profit: 0.875
# Total profit: 1

# %%
import matplotlib.pyplot as plt

selfish_power = list(sim_range_selfish)
honest_power = list(sim_range_honest)

fig, axs = plt.subplots(1, 2, figsize=(15,5))

axs[0].plot(honest_power, selfish_profits, label = "selfish mining")
axs[0].plot(honest_power, honest_profits, label = "honest mining")
axs[0].tick_params(axis='x', colors='red')
axs[0].tick_params(axis='y', colors='red')
axs[0].set_xlabel('Honest Network Power').set_color('red')
axs[0].set_ylabel('Persentage of Mined Blocks (Profit)').set_color('red')
axs[0].legend()

axs[1].plot(selfish_power, selfish_profits, label = "selfish mining")
axs[1].plot(selfish_power, honest_profits, label = "honest mining")
axs[1].tick_params(axis='x', colors='red')
axs[1].tick_params(axis='y', colors='red')
axs[1].set_xlabel('Selfish Network Power').set_color('red')
axs[1].set_ylabel('Persentage of Mined Blocks (Profit)').set_color('red')
axs[1].legend()
